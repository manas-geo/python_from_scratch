# %% [markdown]
# <a href="https://colab.research.google.com/github/manas-geo/python_from_scratch/blob/main/print_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(5.9)
# Out:
# 5.9

# %%
print("true")
# Out:
# true
