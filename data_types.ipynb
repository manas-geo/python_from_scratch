# %% [markdown]
# <a href="https://colab.research.google.com/github/manas-geo/python_from_scratch/blob/main/data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Basic types- integer, float, boolean, and string
#container types- list, tuples, sets, and disctionary
#user defined - class

# %%
#integer
print (7)
print(1e308)
print(1e309) #highest printing range
# Out:
# 7
# 1e+308
# inf

# %%
#float
print(4.5)
print(1.7e308)
print(1.7e309) #highest printing range
# Out:
# 4.5
# 1.7e+308
# inf

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#complex
print(4+6j)
# Out:
# (4+6j)

# %%
#string
print('kolkata')
print('delhi')
# Out:
# kolkata
# delhi

# %%
#list
print([1, 2, 3, 4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2.3,4,5))
# Out:
# (1, 2.3, 4, 5)

# %%
#sets
print({1,2,3,4,5,6})
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# dict
print({'name': 'manas', 'age': 30, 'gender': 'male'})
# Out:
# {'name': 'manas', 'age': 30, 'gender': 'male'}

# %%
person = ({'name': 'manas', 'age': 30, 'gender': 'male'})
print(person)
# Out:
# {'name': 'manas', 'age': 30, 'gender': 'male'}
