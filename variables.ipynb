# %% [markdown]
# <a href="https://colab.research.google.com/github/manas-geo/python_from_scratch/blob/main/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = 'manas'
roll = 5

print(name)
print(roll)
# Out:
# manas
# 5

# %%
#dynamic binding
name = True
print(name)
# Out:
# True

# %%
#special syntex
a = 5; b=6;c=7
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a,b,c = 4,5,6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a=b=c =6
print(a)
print(b)
print(c)
# Out:
# 6
# 6
# 6
